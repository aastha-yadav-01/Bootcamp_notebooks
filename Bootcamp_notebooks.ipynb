# %% [markdown]
# <a href="https://colab.research.google.com/github/aastha-yadav-01/Bootcamp_notebooks/blob/main/Bootcamp_notebooks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
print("I Am ALL SET FOR PYTHON")
# Out:
# I Am ALL SET FOR PYTHON

# %%
l=["Math", "Physics", "Chemistry", "Java", "ML"]
print(l[0],l[-1])
# Out:
# Math ML

# %%
l=[23,-42 ,4324,43,423765-8,0]
for i in l:
  if(i>0):
    print("POSITIVE")
  elif (i<0):
    print("NEGATIVE")
  else:
    print("ZERO")
# Out:
# POSITIVE
# NEGATIVE
# POSITIVE
# POSITIVE
# POSITIVE
# ZERO

# %%
transactions = [
    {"transaction_id": "TX101", "amount": 6700, "method": "Credit Card"},
    {"transaction_id": "TX102", "amount": 5597, "method": "Gift Card"},
    {"transaction_id": "TX103", "amount": 1900, "method": "Cash"},
    {"transaction_id": "TX104", "amount": 87680, "method": "Gift Card"},
    {"transaction_id": "TX105", "amount": 450, "method": "PayPal"}
]
flagged_transactions=[]

for i in transactions:
  if i["amount"] > 5000 and i["method"]=="Gift Card":
    flagged_transactions.append(i)

print(flagged_transactions)


# Write your code below to find anomalous patterns
# Out:
# [{'transaction_id': 'TX102', 'amount': 5597, 'method': 'Gift Card'}, {'transaction_id': 'TX104', 'amount': 87680, 'method': 'Gift Card'}]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

url="https://raw.githubusercontent.com/plotly/datasets/master/gapminderDataFiveYear.csv"

df=pd.read_csv(url)


print(df.head())
print(df.shape)
print(df.columns)
print(df.info())
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# (1704, 6)
# Index(['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   year       1704 non-null   int64
#  2   pop        1704 non-null   float64
#  3   continent  1704 non-null   object
#  4   lifeExp    1704 non-null   float64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# ...

# %%
print(df)
print("First 5 rows:")
print(df.head())

print("\nShape (rows, columns):")
print(df.shape)

print("\nNumber of countries:")
print(df['country'].nunique())

print("\nNumber of continents:")
print(df['continent'].nunique())

print("\nCountries in each continent:")
print(df['continent'].value_counts())

print("\nMissing values:")
print(df.isnull().sum())

print("\nAverage life expectancy:")
print(df['lifeExp'].mean())

print("\nAverage GDP per capita:")
print(df['gdpPercap'].mean())

print("\nHighest GDP country:")
print(df.loc[df['gdpPercap'].idxmax()])
# Out:
#           country  year         pop continent  lifeExp   gdpPercap
# 0     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]
# First 5 rows:
#        country  year         pop continent  lifeExp   gdpPercap
# ...

# %%
# 1. Print the value counts for each continent
print(df["continent"].value_counts())

print("\n--- Continent Summary (Means) ---")

# 2. Group by continent and calculate the mean for the correct column names
continent_summary = df.groupby("continent")[[
    "lifeExp",      # Matches 'life_expectancy'
    "gdpPercap",    # Matches 'gdp_per_capita'
    "pop"           # Matches 'population'
]].mean()

print(continent_summary)
# Out:
# continent
# Africa      624
# Asia        396
# Europe      360
# Americas    300
# Oceania      24
# Name: count, dtype: int64
#
# --- Continent Summary (Means) ---
#              lifeExp     gdpPercap           pop
# continent
# Africa     48.865330   2193.754578  9.916003e+06
# Americas   64.658737   7136.110356  2.450479e+07
# Asia       60.064903   7902.150428  7.703872e+07
# Europe     71.903686  14469.475533  1.716976e+07
# Oceania    74.326208  18621.609223  8.874672e+06

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/plotly/datasets/master/gapminderDataFiveYear.csv"

df = pd.read_csv(url)

data = df.groupby("continent")["lifeExp"].mean()

plt.bar(data.index, data.values)

plt.xlabel("Continent")
plt.ylabel("Average Life Expectancy")
plt.title("Average Life Expectancy vs Continent")

plt.show()

# %%
data = df[df["country"].isin(["India","China","United States"])]

plt.figure(figsize=(8,5))

for country in data["country"].unique():
    temp = data[data["country"] == country]
    plt.plot(temp["year"], temp["lifeExp"], marker="o", label=country)

plt.xlabel("Year")
plt.ylabel("Life Expectancy")
plt.title("Life Expectancy Over Time")

plt.legend()

# %%
plt.figure(figsize=(9,5))

plt.scatter(df["gdpPercap"], df["lifeExp"])

plt.xlabel("GDP per Capita")
plt.ylabel("Life Expectancy")
plt.title("GDP per Capita vs Life Expectancy")

plt.show()

# %%
#architecture of lstm
#layers and shape
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
'''import tensorflow as tf #mathmatical function,tensors manuplating tools
from tensorflow import Sequence
from tensorflow.keras import layers # keras is an api for tensorflow jaha operation kr skte hai'''

vocab_size=1000 #unique words or unique tokens
embedding_dim=16
sequence_length=8

#model architecture of lstm

lstm_model = Sequential(
    [
                #layer 1 ;input wording embeddings
                Embedding(
                    input_dim=vocab_size,
                    output_dim=embedding_dim,
                    input_length=sequence_length, # will takes 8 words , 8 integers
                    name="embedding_layer"
                ),

                #layer 2: Sequence processing (RNN base-with lstm touch)
                LSTM(units=32,name="lstm_layer"), # it will process 32 internal memory cell info --- it procesess 8 vectors

                #layer 3:output binary classification
                Dense(units=1,activation="sigmoid",name="output later")



    ],
     name="Sequential_LSTM_Classifier"

)
#3 verification
lstm_model.summary()
# Out:
# Model: "Sequential_LSTM_Classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_layer (Embedding)     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_layer (LSTM)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output later (Dense)            │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class SelfAttention(nn.Module):

    def __init__(self, embed_size):
        super().__init__()

        # Linear vector creation
        self.query = nn.Linear(embed_size, embed_size)
        self.key = nn.Linear(embed_size, embed_size)
        self.value = nn.Linear(embed_size, embed_size)

    def forward(self, x):
        # Q, K, V transformation
        Q = self.query(x)
        K = self.key(x)
        V = self.value(x)

        # Scaling factor
        scale = x.shape[-1] ** 0.5

        # Matrix multiplication (dot product)
        scores = Q @ K.transpose(-2, -1) / scale

        # Convert scores into probabilities
        attention_weights = F.softmax(scores, dim=-1)

        # Weighted sum of values
        return attention_weights @ V

# %%
  # Transformer Encoder
class TransformerBlock(nn.Module):

    def __init__(self, embed_size):
        super().__init__()

        self.attention = SelfAttention(embed_size)

        self.norm1 = nn.LayerNorm(embed_size)
        self.norm2 = nn.LayerNorm(embed_size)

        self.feed_forward = nn.Sequential(
            nn.Linear(embed_size, embed_size * 4),
            nn.ReLU(),
            nn.Linear(embed_size * 4, embed_size)
        )

    def forward(self, x):

        attention_out = self.attention(x)
        x = self.norm1(attention_out + x)

        ff_out = self.feed_forward(x)

        return self.norm2(ff_out + x)

# %%
embed_size = 256
sequence_length = 10
batch_size = 32

model = TransformerBlock(embed_size)

dummy_input = torch.randn(batch_size, sequence_length, embed_size)

output = model(dummy_input)

print(output.shape)
# Out:
# torch.Size([32, 10, 256])
