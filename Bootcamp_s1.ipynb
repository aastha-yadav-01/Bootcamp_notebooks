# %% [markdown]
# <a href="https://colab.research.google.com/github/aastha-yadav-01/Bootcamp_notebooks/blob/main/Bootcamp_s1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
marks = [45, 60, 72, 38, 90]

total = 0

for i in range(len(marks) - 1):
    total += marks[i]

average = total / len(marks)

if average > 50:
    print("Class passed")
else:
    print("Class failed")

print("Average:", average)
# Out:
# Class failed
# Average: 43.0

# %%
#AI HARNESS IDE
#Orhcestrator software

# %%
#SPAM mail
#legitimate mail id
#payloads
#unusual IPs
#suspicious links


#LEGAL mails
#keyword recognition
#character recognition
#CTA
#HILF







##keyword recognition
#SPAM                                                 #legitimate
brand name manipulation                               #information completness
#CTA (immediate call to action)                                                  #proper file extensions
#more punctuation                                       #signature




#Call to action
#immediate account termination
#direct asking for PII (personal idenfiable info)
#limited time offers

# %%
#rule based-DONE
#Ml model-
#LLM systems-Agentic AI systems

LInked--instagram\


#pandas or #sour

# %%
#NOT statement
